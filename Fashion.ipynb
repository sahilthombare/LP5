# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#Load Dataset

# %%
train_df = pd.read_csv('fashion-mnist_train.csv')
test_df = pd.read_csv('fashion-mnist_test.csv')

# %%
train_df.shape
# Out:
# (60000, 785)

# %%
test_df.shape
# Out:
# (10000, 785)

# %%
train_df.describe()
# Out:
#               label        pixel1        pixel2        pixel3        pixel4  \
# count  60000.000000  60000.000000  60000.000000  60000.000000  60000.000000
# mean       4.500000      0.000900      0.006150      0.035333      0.101933
# std        2.872305      0.094689      0.271011      1.222324      2.452871
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        2.000000      0.000000      0.000000      0.000000      0.000000
# 50%        4.500000      0.000000      0.000000      0.000000      0.000000
# 75%        7.000000      0.000000      0.000000      0.000000      0.000000
# max        9.000000     16.000000     36.000000    226.000000    164.000000
#
#              pixel5        pixel6        pixel7        pixel8        pixel9  \
# count  60000.000000  60000.000000  60000.000000  60000.000000  60000.000000
# mean       0.247967      0.411467      0.805767      2.198283      5.682000
# std        4.306912      5.836188      8.215169     14.093378     23.819481
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max      227.000000    230.000000    224.000000    255.000000    254.000000
#
#        ...      pixel775      pixel776      pixel777      pixel778  \
# count  ...  60000.000000  60000.000000  60000.000000  60000.000000
# mean   ...     34.625400     23.300683     16.588267     17.869433
# std    ...     57.545242     48.854427     41.979611     43.966032
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...      0.000000      0.000000      0.000000      0.000000
# 50%    ...      0.000000      0.000000      0.000000      0.000000
# 75%    ...     58.000000      9.000000      0.000000      0.000000
# max    ...    255.000000    255.000000    255.000000    255.000000
#
#            pixel779      pixel780      pixel781      pixel782      pixel783  \
# count  60000.000000  60000.000000  60000.000000  60000.000000  60000.000000
# mean      22.814817     17.911483      8.520633      2.753300      0.855517
# std       51.830477     45.149388     29.614859     17.397652      9.356960
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max      255.000000    255.000000    255.000000    255.000000    255.000000
#
#           pixel784
# count  60000.00000
# mean       0.07025
# std        2.12587
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        0.00000
# max      170.00000
#
# [8 rows x 785 columns]

# %%
train_df.label.unique()
# Out:
# array([2, 9, 6, 0, 3, 4, 5, 8, 7, 1], dtype=int64)

# %%
#Each row represents an grayscale image containing 784 pixels and each pixel having values in range from 0-255
#The column label is a discrete value in the range 0 to 9 each value representing a specific category

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat','Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
#Preprocess Data
#Convert each image of 784 into (28x28x1)(height x width x color_channels). Divide values by 255 to scale the values.

# %%
x_train = train_df.iloc[:,1:].to_numpy()
x_train = x_train.reshape([-1,28,28,1])
x_train = x_train / 255

# %%
y_train = train_df.iloc[:,0].to_numpy()

# %%
x_test = test_df.iloc[:,1:].to_numpy()
x_test = x_test.reshape([-1,28,28,1])
x_test = x_test / 255

# %%
y_test = test_df.iloc[:,0].to_numpy()

# %%
#Visualization

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %%
#Model Building

# %%
from keras.models import Sequential
from keras.layers import Dense,Conv2D,Flatten,MaxPooling2D,Dropout
# Out:
# C:\Users\sahil\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
model = Sequential()

model.add(Conv2D(filters=64,kernel_size=(3,3),input_shape=(28,28,1),activation='relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(rate=0.3))
model.add(Flatten())
model.add(Dense(units=32, activation='relu'))
model.add(Dense(units=10, activation='sigmoid'))
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# C:\Users\sahil\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 26, 26, 64)          │             640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 13, 13, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 13, 13, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 10816)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 32)                  │         346,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │             330 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 347,114 (1.32 MB)
#  Trainable params: 347,114 (1.32 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(x_train,y_train,epochs=50,batch_size=1200,validation_split=0.05)
# Out:
# Epoch 1/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 23s 386ms/step - accuracy: 0.5769 - loss: 1.2443 - val_accuracy: 0.8113 - val_loss: 0.5232
# Epoch 2/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 382ms/step - accuracy: 0.8275 - loss: 0.4873 - val_accuracy: 0.8457 - val_loss: 0.4389
# Epoch 3/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 378ms/step - accuracy: 0.8536 - loss: 0.4212 - val_accuracy: 0.8637 - val_loss: 0.3923
# Epoch 4/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 21s 380ms/step - accuracy: 0.8669 - loss: 0.3780 - val_accuracy: 0.8740 - val_loss: 0.3750
# Epoch 5/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 21s 385ms/step - accuracy: 0.8755 - loss: 0.3557 - val_accuracy: 0.8810 - val_loss: 0.3503
# Epoch 6/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 382ms/step - accuracy: 0.8831 - loss: 0.3347 - val_accuracy: 0.8780 - val_loss: 0.3449
# Epoch 7/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 21s 382ms/step - accuracy: 0.8864 - loss: 0.3250 - val_accuracy: 0.8900 - val_loss: 0.3225
# Epoch 8/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 21s 385ms/step - accuracy: 0.8927 - loss: 0.3105 - val_accuracy: 0.8820 - val_loss: 0.3295
# Epoch 9/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 381ms/step - accuracy: 0.8933 - loss: 0.3042 - val_accuracy: 0.8917 - val_loss: 0.3120
# Epoch 10/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 381ms/step - accuracy: 0.8957 - loss: 0.2956 - val_accuracy: 0.8917 - val_loss: 0.3060
# Epoch 11/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 21s 387ms/step - accuracy: 0.8986 - loss: 0.2895 - val_accuracy: 0.8903 - val_loss: 0.3077
# Epoch 12/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 380ms/step - accuracy: 0.8996 - loss: 0.2852 - val_accuracy: 0.8950 - val_loss: 0.2971
# Epoch 13/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 21s 381ms/step - accuracy: 0.9030 - loss: 0.2742 - val_accuracy: 0.8977 - val_loss: 0.2946
# Epoch 14/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 379ms/step - accuracy: 0.9035 - loss: 0.2711 - val_accuracy: 0.8990 - val_loss: 0.2852
# Epoch 15/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 373ms/step - accuracy: 0.9061 - loss: 0.2621 - val_accuracy: 0.8993 - val_loss: 0.2832
# Epoch 16/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 369ms/step - accuracy: 0.9065 - loss: 0.2601 - val_accuracy: 0.9057 - val_loss: 0.2784
# Epoch 17/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 21s 368ms/step - accuracy: 0.9084 - loss: 0.2551 - val_accuracy: 0.9027 - val_loss: 0.2770
# Epoch 18/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 390ms/step - accuracy: 0.9097 - loss: 0.2525 - val_accuracy: 0.9010 - val_loss: 0.2784
# Epoch 19/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 379ms/step - accuracy: 0.9116 - loss: 0.2522 - val_accuracy: 0.9073 - val_loss: 0.2711
# Epoch 20/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 381ms/step - accuracy: 0.9132 - loss: 0.2435 - val_accuracy: 0.9060 - val_loss: 0.2708
# Epoch 21/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 19s 385ms/step - accuracy: 0.9155 - loss: 0.2356 - val_accuracy: 0.9017 - val_loss: 0.2748
# Epoch 22/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 383ms/step - accuracy: 0.9157 - loss: 0.2338 - val_accuracy: 0.9080 - val_loss: 0.2623
# Epoch 23/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 382ms/step - accuracy: 0.9181 - loss: 0.2288 - val_accuracy: 0.9073 - val_loss: 0.2692
# Epoch 24/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 377ms/step - accuracy: 0.9189 - loss: 0.2275 - val_accuracy: 0.9043 - val_loss: 0.2693
# Epoch 25/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 19s 387ms/step - accuracy: 0.9210 - loss: 0.2220 - val_accuracy: 0.9080 - val_loss: 0.2628
# Epoch 26/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 418ms/step - accuracy: 0.9204 - loss: 0.2212 - val_accuracy: 0.9087 - val_loss: 0.2592
# Epoch 27/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 382ms/step - accuracy: 0.9195 - loss: 0.2215 - val_accuracy: 0.9077 - val_loss: 0.2582
# Epoch 28/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 21s 388ms/step - accuracy: 0.9227 - loss: 0.2118 - val_accuracy: 0.9147 - val_loss: 0.2554
# Epoch 29/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 380ms/step - accuracy: 0.9235 - loss: 0.2135 - val_accuracy: 0.9060 - val_loss: 0.2568
# Epoch 30/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 375ms/step - accuracy: 0.9251 - loss: 0.2105 - val_accuracy: 0.9043 - val_loss: 0.2616
# Epoch 31/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 381ms/step - accuracy: 0.9253 - loss: 0.2076 - val_accuracy: 0.9077 - val_loss: 0.2583
# Epoch 32/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 21s 383ms/step - accuracy: 0.9239 - loss: 0.2084 - val_accuracy: 0.9090 - val_loss: 0.2582
# Epoch 33/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 19s 384ms/step - accuracy: 0.9267 - loss: 0.2042 - val_accuracy: 0.9173 - val_loss: 0.2513
# Epoch 34/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 21s 383ms/step - accuracy: 0.9266 - loss: 0.1986 - val_accuracy: 0.9150 - val_loss: 0.2528
# Epoch 35/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 19s 385ms/step - accuracy: 0.9284 - loss: 0.1978 - val_accuracy: 0.9103 - val_loss: 0.2520
# Epoch 36/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 21s 385ms/step - accuracy: 0.9274 - loss: 0.1989 - val_accuracy: 0.9137 - val_loss: 0.2488
# Epoch 37/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 381ms/step - accuracy: 0.9306 - loss: 0.1928 - val_accuracy: 0.9130 - val_loss: 0.2509
# Epoch 38/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 19s 385ms/step - accuracy: 0.9288 - loss: 0.1937 - val_accuracy: 0.9170 - val_loss: 0.2463
# Epoch 39/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 381ms/step - accuracy: 0.9323 - loss: 0.1850 - val_accuracy: 0.9147 - val_loss: 0.2472
# Epoch 40/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 371ms/step - accuracy: 0.9322 - loss: 0.1882 - val_accuracy: 0.9147 - val_loss: 0.2454
# Epoch 41/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 382ms/step - accuracy: 0.9321 - loss: 0.1864 - val_accuracy: 0.9170 - val_loss: 0.2436
# Epoch 42/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 19s 389ms/step - accuracy: 0.9342 - loss: 0.1817 - val_accuracy: 0.9183 - val_loss: 0.2446
# Epoch 43/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 380ms/step - accuracy: 0.9337 - loss: 0.1805 - val_accuracy: 0.9173 - val_loss: 0.2474
# Epoch 44/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 381ms/step - accuracy: 0.9336 - loss: 0.1813 - val_accuracy: 0.9093 - val_loss: 0.2552
# Epoch 45/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 19s 387ms/step - accuracy: 0.9368 - loss: 0.1768 - val_accuracy: 0.9157 - val_loss: 0.2509
# Epoch 46/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 383ms/step - accuracy: 0.9376 - loss: 0.1722 - val_accuracy: 0.9167 - val_loss: 0.2473
# Epoch 47/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 380ms/step - accuracy: 0.9386 - loss: 0.1721 - val_accuracy: 0.9173 - val_loss: 0.2445
# Epoch 48/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 380ms/step - accuracy: 0.9377 - loss: 0.1717 - val_accuracy: 0.9137 - val_loss: 0.2450
# Epoch 49/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 21s 384ms/step - accuracy: 0.9396 - loss: 0.1689 - val_accuracy: 0.9157 - val_loss: 0.2443
# Epoch 50/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 382ms/step - accuracy: 0.9388 - loss: 0.1659 - val_accuracy: 0.9157 - val_loss: 0.2447

# %%
#Evaluation

# %%
evaluation = model.evaluate(x_test,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9211 - loss: 0.2268

# %%
print(f"Accuracy: {evaluation[1]}")
# Out:
# Accuracy: 0.9226999878883362

# %%
y_probas = model.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step

# %%
y_pred = y_probas.argmax(axis=-1)

# %%
y_pred
# Out:
# array([0, 1, 2, ..., 8, 8, 1], dtype=int64)

# %%
plt.figure(figsize=(10,10),)
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_test[i], cmap=plt.cm.binary)
#     plt.xlabel(f"True Class:{y_test[i]}")
    plt.title(f"Pred:{class_names[y_pred[i]]}")
plt.show()

# %%
from sklearn.metrics import classification_report

# %%
num_classes = 10
class_names = ["class {}".format(i) for i in range(num_classes)]
cr = classification_report(y_test, y_pred, target_names=class_names)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.84      0.90      0.87      1000
#      class 1       0.98      0.99      0.99      1000
#      class 2       0.88      0.89      0.88      1000
#      class 3       0.94      0.92      0.93      1000
#      class 4       0.88      0.90      0.89      1000
#      class 5       0.99      0.98      0.98      1000
#      class 6       0.81      0.75      0.78      1000
#      class 7       0.96      0.95      0.96      1000
#      class 8       0.98      0.98      0.98      1000
#      class 9       0.95      0.97      0.96      1000
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.92      0.92     10000
# weighted avg       0.92      0.92      0.92     10000
